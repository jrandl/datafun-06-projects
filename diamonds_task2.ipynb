# %% [markdown]
# # Task 2 - Guided Diamonds Project
# ## Author: Josiah Randleman
# ## Date: 9/27/2023

# %% [markdown]
# ---

# %% [markdown]
# ## Section 1-Load: Get the file, store it in your repo, and load it into a DataFrame

# %%
import pandas as pd

# Read the 'diamonds.csv' file into a DataFrame
diamonds = pd.read_csv('diamonds.csv', index_col=0)

# Set the display precision to 2 decimal places
pd.set_option('display.precision', 2)

# Display the 'diamonds' DataFrame
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2-View: Display the first 7 rows and the last 7 rows.

# %%
import pandas as pd

diamonds = pd.read_csv('diamonds.csv', index_col=0)

pd.set_option('display.precision', 2)

# Display the first 7 rows
first_7_rows = diamonds.head(7)

# Display the last 7 rows
last_7_rows = diamonds.tail(7)

# Combine the two dataframes vertically
result = pd.concat([first_7_rows, last_7_rows])

print(result)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 6       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Section 3-Describe: Use the DataFrame describe() function to calculate basic descriptive statistics for all numeric columns

# %%
import pandas as pd

# Read the 'diamonds.csv' file into a DataFrame
diamonds = pd.read_csv('diamonds.csv', index_col=0)

# Set the display precision to 2 decimal places
pd.set_option('display.precision', 2)

# Display the 'diamonds' DataFrame
diamonds.describe()
# Out:
#           carat     depth     table     price         x         y         z
# count  53940.00  53940.00  53940.00  53940.00  53940.00  53940.00  53940.00
# mean       0.80     61.75     57.46   3932.80      5.73      5.73      3.54
# std        0.47      1.43      2.23   3989.44      1.12      1.14      0.71
# min        0.20     43.00     43.00    326.00      0.00      0.00      0.00
# 25%        0.40     61.00     56.00    950.00      4.71      4.72      2.91
# 50%        0.70     61.80     57.00   2401.00      5.70      5.71      3.53
# 75%        1.04     62.50     59.00   5324.25      6.54      6.54      4.04
# max        5.01     79.00     95.00  18823.00     10.74     58.90     31.80

# %% [markdown]
# ---

# %% [markdown]
# ## Section 4-Series: Use the Series method describe() to calculate the descriptive stats for all category/text columns

# %%
import pandas as pd

# Read the 'diamonds.csv' file into a DataFrame
diamonds = pd.read_csv('diamonds.csv', index_col=0)

# Set the display precision to 2 decimal places
pd.set_option('display.precision', 2)

# Display the 'diamonds' DataFrame
diamonds.describe(include='object')
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ---

# %% [markdown]
# ## Section 5-Unique: Use the Series method unique() to get unique category values

# %%
import pandas as pd

# Read the 'diamonds.csv' file into a DataFrame
diamonds = pd.read_csv('diamonds.csv', index_col=0)

# Set the display precision to 2 decimal places
pd.set_option('display.precision', 2)

# Find the unique values in the category values
unique_values_cut = diamonds['cut'].unique()
unique_values_color = diamonds['color'].unique()
unique_values_clarity = diamonds['clarity'].unique()

# Display the unique values
print(unique_values_cut)
print(unique_values_color)
print(unique_values_clarity)
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %% [markdown]
# ---

# %% [markdown]
# ## Section 6-Histograms: Use the DataFrame's hist() function to create a histogram for each numerical column

# %%
import pandas as pd
import matplotlib.pyplot as plt
import chardet

# Detect the encoding of the CSV file
with open('diamonds.csv', 'rb') as f:
    result = chardet.detect(f.read())

diamonds = pd.read_csv('diamonds.csv', encoding=result['encoding'])

# Set the display precision to 2 decimal places
pd.set_option('display.precision', 2)

columns_of_interest = [
    'carat', 'depth', 'table', 'price', 'x', 'y', 'z'
]

# Loop through each column and plot individual histograms
for col in columns_of_interest:
    plt.figure(figsize=(10, 5))  # Set the figure size for each plot
    diamonds[col].hist(bins=20)  # Adjust the number of bins if needed
    plt.title(f'Histogram of {col}')  # Set the title
    plt.xlabel(col)  # Set x-axis label
    plt.ylabel('Frequency')  # Set y-axis label
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---
